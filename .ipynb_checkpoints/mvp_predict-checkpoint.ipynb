# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.model_selection import cross_val_score
import torch
from torch.autograd import Variable as V
import torch.nn.functional as F
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader

from sklearn.metrics import accuracy_score

player_stat_00_01 = pd.read_csv("play_per_game_stat/00-01.csv",delimiter = ",")        
player_stat_01_02 = pd.read_csv("play_per_game_stat/01-02.csv",delimiter = ",")
player_stat_02_03 = pd.read_csv("play_per_game_stat/02-03.csv",delimiter = ",")
player_stat_03_04 = pd.read_csv("play_per_game_stat/03-04.csv",delimiter = ",")
player_stat_04_05 = pd.read_csv("play_per_game_stat/04-05.csv",delimiter = ",")
player_stat_05_06 = pd.read_csv("play_per_game_stat/05-06.csv",delimiter = ",")
player_stat_06_07 = pd.read_csv("play_per_game_stat/06-07.csv",delimiter = ",")
player_stat_07_08 = pd.read_csv("play_per_game_stat/07-08.csv",delimiter = ",")
player_stat_08_09 = pd.read_csv("play_per_game_stat/08-09.csv",delimiter = ",")
player_stat_09_10 = pd.read_csv("play_per_game_stat/09-10.csv",delimiter = ",")

player_stat_10_11 = pd.read_csv("play_per_game_stat/10-11.csv",delimiter = ",")
player_stat_11_12 = pd.read_csv("play_per_game_stat/11-12.csv",delimiter = ",")
player_stat_12_13 = pd.read_csv("play_per_game_stat/12-13.csv",delimiter = ",")
player_stat_13_14 = pd.read_csv("play_per_game_stat/13-14.csv",delimiter = ",")
player_stat_14_15 = pd.read_csv("play_per_game_stat/14-15.csv",delimiter = ",")
player_stat_15_16 = pd.read_csv("play_per_game_stat/15-16.csv",delimiter = ",")
player_stat_16_17 = pd.read_csv("play_per_game_stat/16-17.csv",delimiter = ",")

stat_00_10 = [player_stat_00_01,player_stat_01_02,player_stat_02_03,player_stat_03_04,player_stat_04_05,
             player_stat_05_06,player_stat_06_07,player_stat_07_08,player_stat_08_09,player_stat_09_10]
              
stat_10_17 = [ player_stat_10_11,player_stat_11_12,player_stat_12_13,
              player_stat_13_14,player_stat_14_15,player_stat_15_16,player_stat_16_17] 

mvp_train_dataframe = pd.read_csv("mvp/mvp_train.csv",delimiter = ",")
mvp_test_dataframe = pd.read_csv("mvp/mvp_test.csv",delimiter = ",")                                 
def initialize_data(stat,mvp_dataframe):
    a=[]
    mvp_list = []
    dataframe = pd.read_csv("play_per_game_stat/template.csv",delimiter = ",")
    dataframe = dataframe.drop(["Pos","Tm","Rk"],axis=1)
    for i in range(len(stat)):
        a.append(stat[i].drop(["Pos","Tm","Rk"],axis=1))
        
        column_num = a[i].shape[0]
        a[i].fillna(0,inplace = True)
        for j in range(column_num):
            if(a[i].loc[j,"Player"].find("*") != -1):
                a[i].loc[j,"Player"] = a[i].loc[j,"Player"][0:a[i].loc[j,"Player"].find("*")]
            if(a[i].loc[j,"Player"].find("\\") != -1):
                a[i].loc[j,"Player"] = a[i].loc[j,"Player"][0:a[i].loc[j,"Player"].find("\\")] 
            if( a[i].loc[j,"Player"] == mvp_dataframe.loc[i,"name"] ):
                print(mvp_dataframe.loc[i,"name"])
                mvp_list.append(1)
            else:
                mvp_list.append(0)
        dataframe = dataframe.append(a[i])
        dataframe = dataframe.reset_index(drop=True)  # 来改变index就可以了,
#         print(column_num)
    dataframe_with_player_name = dataframe
    dataframe = dataframe.drop(["Player"],axis=1)
    dataframe=pd.DataFrame(dataframe,dtype=np.float)
    return (dataframe_with_player_name,dataframe,mvp_list)

dataframe_00_10_with_player_name, dataframe_00_10 , mvp_list_train  = initialize_data(stat_00_10,mvp_train_dataframe)
print()
dataframe_10_17_with_player_name ,dataframe_10_17, mvp_list_test = initialize_data(stat_10_17,mvp_test_dataframe)
# print(dataframe_10_17.info())
# print(dataframe_10_17_with_player_name.info())
print(len(mvp_list_test))
print("10-17 mvps:")
for i in range(1623):
    if(mvp_list_test[i] == 1):
        print(dataframe_10_17_with_player_name.loc[i,"Player"] , i)
# Out:
# Allen Iverson
# Tim Duncan
# Tim Duncan
# Kevin Garnett
# Steve Nash
# Steve Nash
# Dirk Nowitzki
# Kobe Bryant
# LeBron James
# LeBron James
#
# Derrick Rose
# LeBron James
# LeBron James
# Kevin Durant
# Stephen Curry
# Stephen Curry
# Russell Westbrook
# 1623
# 10-17 mvps:
# Derrick Rose 6
# LeBron James 188
# LeBron James 375
# Kevin Durant 555
# Stephen Curry 819
# Stephen Curry 1081
# Russell Westbrook 1352

# %%
X_train = torch.tensor(np.array(dataframe_00_10),dtype=torch.float) 
y_train = torch.tensor(mvp_list_train,dtype=torch.float).view(-1,1)

X_test = torch.tensor(np.array(dataframe_10_17),dtype=torch.float) 
y_test = torch.tensor(mvp_list_test,dtype=torch.float).view(-1,1)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)

class Model(torch.nn.Module): 
    def __init__(self):
        super(Model, self).__init__() 
        self.linear1 = torch.nn.Linear(26, 10) 
        self.linear2 = torch.nn.Linear(10, 1) 
        self.sigmoid = torch.nn.Sigmoid()  #和上节的nn.function下的不一样
#         self.activate = torch.nn.Relu()
    def forward(self, x):
        x = self.sigmoid(self.linear1(x)) 
        x = self.sigmoid(self.linear2(x)) 
        return x
model = Model()
criterion = torch.nn.BCELoss(size_average=True)
optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

for epoch in range(30): 
    # Forward
    #注意这里没有minibatch，是整个batch
    y_pred = model(X_train)
    loss = criterion(y_pred, y_train)
#     print(epoch, loss.item())
    # Backward
    optimizer.zero_grad()
    loss.backward()
    # Update
    optimizer.step()

y_pred = model(X_test)
print("??")
for i in range(1623):
    print(i)
    print(y_pred[i])

#     acc = accuracy_score(torch.argmax(y_pred, dim=1).detach().numpy(), y_test)
#     print('Loss at epoch %d : %f, test acc: %f' % (epoch, loss, acc))
# Out:
# torch.Size([1831, 26])
# torch.Size([1831, 1])
# torch.Size([1623, 26])
# torch.Size([1623, 1])
# ??
# 0
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1
# tensor([0.0611], grad_fn=<SelectBackward>)
# 2
# tensor([0.0611], grad_fn=<SelectBackward>)
# 3
# tensor([0.0611], grad_fn=<SelectBackward>)
# 4
# tensor([0.0610], grad_fn=<SelectBackward>)
# 5
# tensor([0.0612], grad_fn=<SelectBackward>)
# 6
# tensor([0.0611], grad_fn=<SelectBackward>)
# 7
# tensor([0.0611], grad_fn=<SelectBackward>)
# 8
# tensor([0.0610], grad_fn=<SelectBackward>)
# 9
# tensor([0.0610], grad_fn=<SelectBackward>)
# 10
# tensor([0.0610], grad_fn=<SelectBackward>)
# 11
# tensor([0.0611], grad_fn=<SelectBackward>)
# 12
# tensor([0.0611], grad_fn=<SelectBackward>)
# 13
# tensor([0.0611], grad_fn=<SelectBackward>)
# 14
# tensor([0.0613], grad_fn=<SelectBackward>)
# 15
# tensor([0.0610], grad_fn=<SelectBackward>)
# 16
# tensor([0.0611], grad_fn=<SelectBackward>)
# 17
# tensor([0.0610], grad_fn=<SelectBackward>)
# 18
# tensor([0.0610], grad_fn=<SelectBackward>)
# 19
# tensor([0.0612], grad_fn=<SelectBackward>)
# 20
# tensor([0.0610], grad_fn=<SelectBackward>)
# 21
# tensor([0.0611], grad_fn=<SelectBackward>)
# 22
# tensor([0.0610], grad_fn=<SelectBackward>)
# 23
# tensor([0.0610], grad_fn=<SelectBackward>)
# 24
# tensor([0.0610], grad_fn=<SelectBackward>)
# 25
# tensor([0.0611], grad_fn=<SelectBackward>)
# 26
# tensor([0.0611], grad_fn=<SelectBackward>)
# 27
# tensor([0.0611], grad_fn=<SelectBackward>)
# 28
# tensor([0.0610], grad_fn=<SelectBackward>)
# 29
# tensor([0.0610], grad_fn=<SelectBackward>)
# 30
# tensor([0.0610], grad_fn=<SelectBackward>)
# 31
# tensor([0.0610], grad_fn=<SelectBackward>)
# 32
# tensor([0.0611], grad_fn=<SelectBackward>)
# 33
# tensor([0.0610], grad_fn=<SelectBackward>)
# 34
# tensor([0.0610], grad_fn=<SelectBackward>)
# 35
# tensor([0.0611], grad_fn=<SelectBackward>)
# 36
# tensor([0.0610], grad_fn=<SelectBackward>)
# 37
# tensor([0.0610], grad_fn=<SelectBackward>)
# 38
# tensor([0.0610], grad_fn=<SelectBackward>)
# 39
# tensor([0.0610], grad_fn=<SelectBackward>)
# 40
# tensor([0.0611], grad_fn=<SelectBackward>)
# 41
# tensor([0.0610], grad_fn=<SelectBackward>)
# 42
# tensor([0.0610], grad_fn=<SelectBackward>)
# 43
# tensor([0.0610], grad_fn=<SelectBackward>)
# 44
# tensor([0.0610], grad_fn=<SelectBackward>)
# 45
# tensor([0.0610], grad_fn=<SelectBackward>)
# 46
# tensor([0.0610], grad_fn=<SelectBackward>)
# 47
# tensor([0.0610], grad_fn=<SelectBackward>)
# 48
# tensor([0.0610], grad_fn=<SelectBackward>)
# 49
# tensor([0.0610], grad_fn=<SelectBackward>)
# 50
# tensor([0.0610], grad_fn=<SelectBackward>)
# 51
# tensor([0.0610], grad_fn=<SelectBackward>)
# 52
# tensor([0.0610], grad_fn=<SelectBackward>)
# 53
# tensor([0.0610], grad_fn=<SelectBackward>)
# 54
# tensor([0.0612], grad_fn=<SelectBackward>)
# 55
# tensor([0.0610], grad_fn=<SelectBackward>)
# 56
# tensor([0.0610], grad_fn=<SelectBackward>)
# 57
# tensor([0.0610], grad_fn=<SelectBackward>)
# 58
# tensor([0.0610], grad_fn=<SelectBackward>)
# 59
# tensor([0.0610], grad_fn=<SelectBackward>)
# 60
# tensor([0.0610], grad_fn=<SelectBackward>)
# 61
# tensor([0.0610], grad_fn=<SelectBackward>)
# 62
# tensor([0.0610], grad_fn=<SelectBackward>)
# 63
# tensor([0.0616], grad_fn=<SelectBackward>)
# 64
# tensor([0.0610], grad_fn=<SelectBackward>)
# 65
# tensor([0.0610], grad_fn=<SelectBackward>)
# 66
# tensor([0.0610], grad_fn=<SelectBackward>)
# 67
# tensor([0.0610], grad_fn=<SelectBackward>)
# 68
# tensor([0.0610], grad_fn=<SelectBackward>)
# 69
# tensor([0.0610], grad_fn=<SelectBackward>)
# 70
# tensor([0.0610], grad_fn=<SelectBackward>)
# 71
# tensor([0.0612], grad_fn=<SelectBackward>)
# 72
# tensor([0.0611], grad_fn=<SelectBackward>)
# 73
# tensor([0.0610], grad_fn=<SelectBackward>)
# 74
# tensor([0.0610], grad_fn=<SelectBackward>)
# 75
# tensor([0.0610], grad_fn=<SelectBackward>)
# 76
# tensor([0.0620], grad_fn=<SelectBackward>)
# 77
# tensor([0.0610], grad_fn=<SelectBackward>)
# 78
# tensor([0.0610], grad_fn=<SelectBackward>)
# 79
# tensor([0.0615], grad_fn=<SelectBackward>)
# 80
# tensor([0.0615], grad_fn=<SelectBackward>)
# 81
# tensor([0.0610], grad_fn=<SelectBackward>)
# 82
# tensor([0.0610], grad_fn=<SelectBackward>)
# 83
# tensor([0.0611], grad_fn=<SelectBackward>)
# 84
# tensor([0.0610], grad_fn=<SelectBackward>)
# 85
# tensor([0.0610], grad_fn=<SelectBackward>)
# 86
# tensor([0.0613], grad_fn=<SelectBackward>)
# 87
# tensor([0.0610], grad_fn=<SelectBackward>)
# 88
# tensor([0.0612], grad_fn=<SelectBackward>)
# 89
# tensor([0.0610], grad_fn=<SelectBackward>)
# 90
# tensor([0.0611], grad_fn=<SelectBackward>)
# 91
# tensor([0.0616], grad_fn=<SelectBackward>)
# 92
# tensor([0.0610], grad_fn=<SelectBackward>)
# 93
# tensor([0.0610], grad_fn=<SelectBackward>)
# 94
# tensor([0.0610], grad_fn=<SelectBackward>)
# 95
# tensor([0.0611], grad_fn=<SelectBackward>)
# 96
# tensor([0.0610], grad_fn=<SelectBackward>)
# 97
# tensor([0.0618], grad_fn=<SelectBackward>)
# 98
# tensor([0.0612], grad_fn=<SelectBackward>)
# 99
# tensor([0.0610], grad_fn=<SelectBackward>)
# 100
# tensor([0.0617], grad_fn=<SelectBackward>)
# 101
# tensor([0.0610], grad_fn=<SelectBackward>)
# 102
# tensor([0.0610], grad_fn=<SelectBackward>)
# 103
# tensor([0.0612], grad_fn=<SelectBackward>)
# 104
# tensor([0.0610], grad_fn=<SelectBackward>)
# 105
# tensor([0.0610], grad_fn=<SelectBackward>)
# 106
# tensor([0.0610], grad_fn=<SelectBackward>)
# 107
# tensor([0.0610], grad_fn=<SelectBackward>)
# 108
# tensor([0.0610], grad_fn=<SelectBackward>)
# 109
# tensor([0.0613], grad_fn=<SelectBackward>)
# 110
# tensor([0.0628], grad_fn=<SelectBackward>)
# 111
# tensor([0.0610], grad_fn=<SelectBackward>)
# 112
# tensor([0.0612], grad_fn=<SelectBackward>)
# 113
# tensor([0.0610], grad_fn=<SelectBackward>)
# 114
# tensor([0.0626], grad_fn=<SelectBackward>)
# 115
# tensor([0.0610], grad_fn=<SelectBackward>)
# 116
# tensor([0.0614], grad_fn=<SelectBackward>)
# 117
# tensor([0.0610], grad_fn=<SelectBackward>)
# 118
# tensor([0.0621], grad_fn=<SelectBackward>)
# 119
# tensor([0.0623], grad_fn=<SelectBackward>)
# 120
# tensor([0.0610], grad_fn=<SelectBackward>)
# 121
# tensor([0.0610], grad_fn=<SelectBackward>)
# 122
# tensor([0.0615], grad_fn=<SelectBackward>)
# 123
# tensor([0.0610], grad_fn=<SelectBackward>)
# 124
# tensor([0.0638], grad_fn=<SelectBackward>)
# 125
# tensor([0.0615], grad_fn=<SelectBackward>)
# 126
# tensor([0.0610], grad_fn=<SelectBackward>)
# 127
# tensor([0.0611], grad_fn=<SelectBackward>)
# 128
# tensor([0.0621], grad_fn=<SelectBackward>)
# 129
# tensor([0.0610], grad_fn=<SelectBackward>)
# 130
# tensor([0.0618], grad_fn=<SelectBackward>)
# 131
# tensor([0.0610], grad_fn=<SelectBackward>)
# 132
# tensor([0.0630], grad_fn=<SelectBackward>)
# 133
# tensor([0.0628], grad_fn=<SelectBackward>)
# 134
# tensor([0.0610], grad_fn=<SelectBackward>)
# 135
# tensor([0.0610], grad_fn=<SelectBackward>)
# 136
# tensor([0.0610], grad_fn=<SelectBackward>)
# 137
# tensor([0.0610], grad_fn=<SelectBackward>)
# 138
# tensor([0.0610], grad_fn=<SelectBackward>)
# 139
# tensor([0.0610], grad_fn=<SelectBackward>)
# 140
# tensor([0.0610], grad_fn=<SelectBackward>)
# 141
# tensor([0.0616], grad_fn=<SelectBackward>)
# 142
# tensor([0.0624], grad_fn=<SelectBackward>)
# 143
# tensor([0.0610], grad_fn=<SelectBackward>)
# 144
# tensor([0.0612], grad_fn=<SelectBackward>)
# 145
# tensor([0.0610], grad_fn=<SelectBackward>)
# 146
# tensor([0.0610], grad_fn=<SelectBackward>)
# 147
# tensor([0.0610], grad_fn=<SelectBackward>)
# 148
# tensor([0.0616], grad_fn=<SelectBackward>)
# 149
# tensor([0.0612], grad_fn=<SelectBackward>)
# 150
# tensor([0.0613], grad_fn=<SelectBackward>)
# 151
# tensor([0.0610], grad_fn=<SelectBackward>)
# 152
# tensor([0.0610], grad_fn=<SelectBackward>)
# 153
# tensor([0.0614], grad_fn=<SelectBackward>)
# 154
# tensor([0.0610], grad_fn=<SelectBackward>)
# 155
# tensor([0.0614], grad_fn=<SelectBackward>)
# 156
# tensor([0.0610], grad_fn=<SelectBackward>)
# 157
# tensor([0.0630], grad_fn=<SelectBackward>)
# 158
# tensor([0.0612], grad_fn=<SelectBackward>)
# 159
# tensor([0.0612], grad_fn=<SelectBackward>)
# 160
# tensor([0.0626], grad_fn=<SelectBackward>)
# 161
# tensor([0.0617], grad_fn=<SelectBackward>)
# 162
# tensor([0.0623], grad_fn=<SelectBackward>)
# 163
# tensor([0.0627], grad_fn=<SelectBackward>)
# 164
# tensor([0.0624], grad_fn=<SelectBackward>)
# 165
# tensor([0.0621], grad_fn=<SelectBackward>)
# 166
# tensor([0.0615], grad_fn=<SelectBackward>)
# 167
# tensor([0.0612], grad_fn=<SelectBackward>)
# 168
# tensor([0.0610], grad_fn=<SelectBackward>)
# 169
# tensor([0.0633], grad_fn=<SelectBackward>)
# 170
# tensor([0.0627], grad_fn=<SelectBackward>)
# 171
# tensor([0.0610], grad_fn=<SelectBackward>)
# 172
# tensor([0.0610], grad_fn=<SelectBackward>)
# 173
# tensor([0.0651], grad_fn=<SelectBackward>)
# 174
# tensor([0.0619], grad_fn=<SelectBackward>)
# 175
# tensor([0.0610], grad_fn=<SelectBackward>)
# 176
# tensor([0.0615], grad_fn=<SelectBackward>)
# 177
# tensor([0.0626], grad_fn=<SelectBackward>)
# 178
# tensor([0.0638], grad_fn=<SelectBackward>)
# 179
# tensor([0.0617], grad_fn=<SelectBackward>)
# 180
# tensor([0.0656], grad_fn=<SelectBackward>)
# 181
# tensor([0.0632], grad_fn=<SelectBackward>)
# 182
# tensor([0.0649], grad_fn=<SelectBackward>)
# 183
# tensor([0.0655], grad_fn=<SelectBackward>)
# 184
# tensor([0.0655], grad_fn=<SelectBackward>)
# 185
# tensor([0.0618], grad_fn=<SelectBackward>)
# 186
# tensor([0.0614], grad_fn=<SelectBackward>)
# 187
# tensor([0.0623], grad_fn=<SelectBackward>)
# 188
# tensor([0.0618], grad_fn=<SelectBackward>)
# 189
# tensor([0.0618], grad_fn=<SelectBackward>)
# 190
# tensor([0.0617], grad_fn=<SelectBackward>)
# 191
# tensor([0.0619], grad_fn=<SelectBackward>)
# 192
# tensor([0.0625], grad_fn=<SelectBackward>)
# 193
# tensor([0.0612], grad_fn=<SelectBackward>)
# 194
# tensor([0.0618], grad_fn=<SelectBackward>)
# 195
# tensor([0.0613], grad_fn=<SelectBackward>)
# 196
# tensor([0.0620], grad_fn=<SelectBackward>)
# 197
# tensor([0.0619], grad_fn=<SelectBackward>)
# 198
# tensor([0.0614], grad_fn=<SelectBackward>)
# 199
# tensor([0.0611], grad_fn=<SelectBackward>)
# 200
# tensor([0.0618], grad_fn=<SelectBackward>)
# 201
# tensor([0.0612], grad_fn=<SelectBackward>)
# 202
# tensor([0.0613], grad_fn=<SelectBackward>)
# 203
# tensor([0.0611], grad_fn=<SelectBackward>)
# 204
# tensor([0.0614], grad_fn=<SelectBackward>)
# 205
# tensor([0.0614], grad_fn=<SelectBackward>)
# 206
# tensor([0.0611], grad_fn=<SelectBackward>)
# 207
# tensor([0.0615], grad_fn=<SelectBackward>)
# 208
# tensor([0.0614], grad_fn=<SelectBackward>)
# 209
# tensor([0.0616], grad_fn=<SelectBackward>)
# 210
# tensor([0.0612], grad_fn=<SelectBackward>)
# 211
# tensor([0.0611], grad_fn=<SelectBackward>)
# 212
# tensor([0.0611], grad_fn=<SelectBackward>)
# 213
# tensor([0.0614], grad_fn=<SelectBackward>)
# 214
# tensor([0.0612], grad_fn=<SelectBackward>)
# 215
# tensor([0.0614], grad_fn=<SelectBackward>)
# 216
# tensor([0.0612], grad_fn=<SelectBackward>)
# 217
# tensor([0.0617], grad_fn=<SelectBackward>)
# 218
# tensor([0.0611], grad_fn=<SelectBackward>)
# 219
# tensor([0.0612], grad_fn=<SelectBackward>)
# 220
# tensor([0.0611], grad_fn=<SelectBackward>)
# 221
# tensor([0.0612], grad_fn=<SelectBackward>)
# 222
# tensor([0.0611], grad_fn=<SelectBackward>)
# 223
# tensor([0.0612], grad_fn=<SelectBackward>)
# 224
# tensor([0.0611], grad_fn=<SelectBackward>)
# 225
# tensor([0.0612], grad_fn=<SelectBackward>)
# 226
# tensor([0.0611], grad_fn=<SelectBackward>)
# 227
# tensor([0.0612], grad_fn=<SelectBackward>)
# 228
# tensor([0.0610], grad_fn=<SelectBackward>)
# 229
# tensor([0.0612], grad_fn=<SelectBackward>)
# 230
# tensor([0.0612], grad_fn=<SelectBackward>)
# 231
# tensor([0.0610], grad_fn=<SelectBackward>)
# 232
# tensor([0.0611], grad_fn=<SelectBackward>)
# 233
# tensor([0.0610], grad_fn=<SelectBackward>)
# 234
# tensor([0.0612], grad_fn=<SelectBackward>)
# 235
# tensor([0.0611], grad_fn=<SelectBackward>)
# 236
# tensor([0.0611], grad_fn=<SelectBackward>)
# 237
# tensor([0.0610], grad_fn=<SelectBackward>)
# 238
# tensor([0.0612], grad_fn=<SelectBackward>)
# 239
# tensor([0.0610], grad_fn=<SelectBackward>)
# 240
# tensor([0.0611], grad_fn=<SelectBackward>)
# 241
# tensor([0.0611], grad_fn=<SelectBackward>)
# 242
# tensor([0.0611], grad_fn=<SelectBackward>)
# 243
# tensor([0.0613], grad_fn=<SelectBackward>)
# 244
# tensor([0.0612], grad_fn=<SelectBackward>)
# 245
# tensor([0.0610], grad_fn=<SelectBackward>)
# 246
# tensor([0.0611], grad_fn=<SelectBackward>)
# 247
# tensor([0.0611], grad_fn=<SelectBackward>)
# 248
# tensor([0.0615], grad_fn=<SelectBackward>)
# 249
# tensor([0.0611], grad_fn=<SelectBackward>)
# 250
# tensor([0.0610], grad_fn=<SelectBackward>)
# 251
# tensor([0.0610], grad_fn=<SelectBackward>)
# 252
# tensor([0.0611], grad_fn=<SelectBackward>)
# 253
# tensor([0.0611], grad_fn=<SelectBackward>)
# 254
# tensor([0.0611], grad_fn=<SelectBackward>)
# 255
# tensor([0.0610], grad_fn=<SelectBackward>)
# 256
# tensor([0.0610], grad_fn=<SelectBackward>)
# 257
# tensor([0.0611], grad_fn=<SelectBackward>)
# 258
# tensor([0.0611], grad_fn=<SelectBackward>)
# 259
# tensor([0.0610], grad_fn=<SelectBackward>)
# 260
# tensor([0.0610], grad_fn=<SelectBackward>)
# 261
# tensor([0.0610], grad_fn=<SelectBackward>)
# 262
# tensor([0.0610], grad_fn=<SelectBackward>)
# 263
# tensor([0.0610], grad_fn=<SelectBackward>)
# 264
# tensor([0.0611], grad_fn=<SelectBackward>)
# 265
# tensor([0.0610], grad_fn=<SelectBackward>)
# 266
# tensor([0.0610], grad_fn=<SelectBackward>)
# 267
# tensor([0.0610], grad_fn=<SelectBackward>)
# 268
# tensor([0.0610], grad_fn=<SelectBackward>)
# 269
# tensor([0.0610], grad_fn=<SelectBackward>)
# 270
# tensor([0.0617], grad_fn=<SelectBackward>)
# 271
# tensor([0.0611], grad_fn=<SelectBackward>)
# 272
# tensor([0.0611], grad_fn=<SelectBackward>)
# 273
# tensor([0.0610], grad_fn=<SelectBackward>)
# 274
# tensor([0.0610], grad_fn=<SelectBackward>)
# 275
# tensor([0.0610], grad_fn=<SelectBackward>)
# 276
# tensor([0.0610], grad_fn=<SelectBackward>)
# 277
# tensor([0.0611], grad_fn=<SelectBackward>)
# 278
# tensor([0.0610], grad_fn=<SelectBackward>)
# 279
# tensor([0.0610], grad_fn=<SelectBackward>)
# 280
# tensor([0.0610], grad_fn=<SelectBackward>)
# 281
# tensor([0.0610], grad_fn=<SelectBackward>)
# 282
# tensor([0.0614], grad_fn=<SelectBackward>)
# 283
# tensor([0.0611], grad_fn=<SelectBackward>)
# 284
# tensor([0.0610], grad_fn=<SelectBackward>)
# 285
# tensor([0.0615], grad_fn=<SelectBackward>)
# 286
# tensor([0.0611], grad_fn=<SelectBackward>)
# 287
# tensor([0.0614], grad_fn=<SelectBackward>)
# 288
# tensor([0.0611], grad_fn=<SelectBackward>)
# 289
# tensor([0.0610], grad_fn=<SelectBackward>)
# 290
# tensor([0.0610], grad_fn=<SelectBackward>)
# 291
# tensor([0.0611], grad_fn=<SelectBackward>)
# 292
# tensor([0.0611], grad_fn=<SelectBackward>)
# 293
# tensor([0.0614], grad_fn=<SelectBackward>)
# 294
# tensor([0.0611], grad_fn=<SelectBackward>)
# 295
# tensor([0.0615], grad_fn=<SelectBackward>)
# 296
# tensor([0.0610], grad_fn=<SelectBackward>)
# 297
# tensor([0.0610], grad_fn=<SelectBackward>)
# 298
# tensor([0.0611], grad_fn=<SelectBackward>)
# 299
# tensor([0.0610], grad_fn=<SelectBackward>)
# 300
# tensor([0.0612], grad_fn=<SelectBackward>)
# 301
# tensor([0.0610], grad_fn=<SelectBackward>)
# 302
# tensor([0.0611], grad_fn=<SelectBackward>)
# 303
# tensor([0.0610], grad_fn=<SelectBackward>)
# 304
# tensor([0.0614], grad_fn=<SelectBackward>)
# 305
# tensor([0.0610], grad_fn=<SelectBackward>)
# 306
# tensor([0.0611], grad_fn=<SelectBackward>)
# 307
# tensor([0.0613], grad_fn=<SelectBackward>)
# 308
# tensor([0.0612], grad_fn=<SelectBackward>)
# 309
# tensor([0.0610], grad_fn=<SelectBackward>)
# 310
# tensor([0.0610], grad_fn=<SelectBackward>)
# 311
# tensor([0.0612], grad_fn=<SelectBackward>)
# 312
# tensor([0.0615], grad_fn=<SelectBackward>)
# 313
# tensor([0.0610], grad_fn=<SelectBackward>)
# 314
# tensor([0.0612], grad_fn=<SelectBackward>)
# 315
# tensor([0.0611], grad_fn=<SelectBackward>)
# 316
# tensor([0.0610], grad_fn=<SelectBackward>)
# 317
# tensor([0.0617], grad_fn=<SelectBackward>)
# 318
# tensor([0.0619], grad_fn=<SelectBackward>)
# 319
# tensor([0.0610], grad_fn=<SelectBackward>)
# 320
# tensor([0.0612], grad_fn=<SelectBackward>)
# 321
# tensor([0.0622], grad_fn=<SelectBackward>)
# 322
# tensor([0.0610], grad_fn=<SelectBackward>)
# 323
# tensor([0.0610], grad_fn=<SelectBackward>)
# 324
# tensor([0.0618], grad_fn=<SelectBackward>)
# 325
# tensor([0.0628], grad_fn=<SelectBackward>)
# 326
# tensor([0.0611], grad_fn=<SelectBackward>)
# 327
# tensor([0.0610], grad_fn=<SelectBackward>)
# 328
# tensor([0.0610], grad_fn=<SelectBackward>)
# 329
# tensor([0.0626], grad_fn=<SelectBackward>)
# 330
# tensor([0.0614], grad_fn=<SelectBackward>)
# 331
# tensor([0.0620], grad_fn=<SelectBackward>)
# 332
# tensor([0.0610], grad_fn=<SelectBackward>)
# 333
# tensor([0.0610], grad_fn=<SelectBackward>)
# 334
# tensor([0.0621], grad_fn=<SelectBackward>)
# 335
# tensor([0.0614], grad_fn=<SelectBackward>)
# 336
# tensor([0.0628], grad_fn=<SelectBackward>)
# 337
# tensor([0.0612], grad_fn=<SelectBackward>)
# 338
# tensor([0.0611], grad_fn=<SelectBackward>)
# 339
# tensor([0.0611], grad_fn=<SelectBackward>)
# 340
# tensor([0.0621], grad_fn=<SelectBackward>)
# 341
# tensor([0.0613], grad_fn=<SelectBackward>)
# 342
# tensor([0.0610], grad_fn=<SelectBackward>)
# 343
# tensor([0.0613], grad_fn=<SelectBackward>)
# 344
# tensor([0.0613], grad_fn=<SelectBackward>)
# 345
# tensor([0.0611], grad_fn=<SelectBackward>)
# 346
# tensor([0.0631], grad_fn=<SelectBackward>)
# 347
# tensor([0.0621], grad_fn=<SelectBackward>)
# 348
# tensor([0.0610], grad_fn=<SelectBackward>)
# 349
# tensor([0.0621], grad_fn=<SelectBackward>)
# 350
# tensor([0.0617], grad_fn=<SelectBackward>)
# 351
# tensor([0.0610], grad_fn=<SelectBackward>)
# 352
# tensor([0.0610], grad_fn=<SelectBackward>)
# 353
# tensor([0.0614], grad_fn=<SelectBackward>)
# 354
# tensor([0.0613], grad_fn=<SelectBackward>)
# 355
# tensor([0.0643], grad_fn=<SelectBackward>)
# 356
# tensor([0.0610], grad_fn=<SelectBackward>)
# 357
# tensor([0.0610], grad_fn=<SelectBackward>)
# 358
# tensor([0.0619], grad_fn=<SelectBackward>)
# 359
# tensor([0.0618], grad_fn=<SelectBackward>)
# 360
# tensor([0.0625], grad_fn=<SelectBackward>)
# 361
# tensor([0.0618], grad_fn=<SelectBackward>)
# 362
# tensor([0.0629], grad_fn=<SelectBackward>)
# 363
# tensor([0.0648], grad_fn=<SelectBackward>)
# 364
# tensor([0.0620], grad_fn=<SelectBackward>)
# 365
# tensor([0.0610], grad_fn=<SelectBackward>)
# 366
# tensor([0.0628], grad_fn=<SelectBackward>)
# 367
# tensor([0.0623], grad_fn=<SelectBackward>)
# 368
# tensor([0.0628], grad_fn=<SelectBackward>)
# 369
# tensor([0.0630], grad_fn=<SelectBackward>)
# 370
# tensor([0.0627], grad_fn=<SelectBackward>)
# 371
# tensor([0.0614], grad_fn=<SelectBackward>)
# 372
# tensor([0.0612], grad_fn=<SelectBackward>)
# 373
# tensor([0.0610], grad_fn=<SelectBackward>)
# 374
# tensor([0.0610], grad_fn=<SelectBackward>)
# 375
# tensor([0.0611], grad_fn=<SelectBackward>)
# 376
# tensor([0.0610], grad_fn=<SelectBackward>)
# 377
# tensor([0.0611], grad_fn=<SelectBackward>)
# 378
# tensor([0.0610], grad_fn=<SelectBackward>)
# 379
# tensor([0.0612], grad_fn=<SelectBackward>)
# 380
# tensor([0.0612], grad_fn=<SelectBackward>)
# 381
# tensor([0.0612], grad_fn=<SelectBackward>)
# 382
# tensor([0.0610], grad_fn=<SelectBackward>)
# 383
# tensor([0.0610], grad_fn=<SelectBackward>)
# 384
# tensor([0.0610], grad_fn=<SelectBackward>)
# 385
# tensor([0.0610], grad_fn=<SelectBackward>)
# 386
# tensor([0.0610], grad_fn=<SelectBackward>)
# 387
# tensor([0.0611], grad_fn=<SelectBackward>)
# 388
# tensor([0.0610], grad_fn=<SelectBackward>)
# 389
# tensor([0.0612], grad_fn=<SelectBackward>)
# 390
# tensor([0.0610], grad_fn=<SelectBackward>)
# 391
# tensor([0.0611], grad_fn=<SelectBackward>)
# 392
# tensor([0.0611], grad_fn=<SelectBackward>)
# 393
# tensor([0.0610], grad_fn=<SelectBackward>)
# 394
# tensor([0.0610], grad_fn=<SelectBackward>)
# 395
# tensor([0.0611], grad_fn=<SelectBackward>)
# 396
# tensor([0.0610], grad_fn=<SelectBackward>)
# 397
# tensor([0.0611], grad_fn=<SelectBackward>)
# 398
# tensor([0.0611], grad_fn=<SelectBackward>)
# 399
# tensor([0.0610], grad_fn=<SelectBackward>)
# 400
# tensor([0.0611], grad_fn=<SelectBackward>)
# 401
# tensor([0.0610], grad_fn=<SelectBackward>)
# 402
# tensor([0.0610], grad_fn=<SelectBackward>)
# 403
# tensor([0.0610], grad_fn=<SelectBackward>)
# 404
# tensor([0.0610], grad_fn=<SelectBackward>)
# 405
# tensor([0.0612], grad_fn=<SelectBackward>)
# 406
# tensor([0.0610], grad_fn=<SelectBackward>)
# 407
# tensor([0.0610], grad_fn=<SelectBackward>)
# 408
# tensor([0.0611], grad_fn=<SelectBackward>)
# 409
# tensor([0.0610], grad_fn=<SelectBackward>)
# 410
# tensor([0.0610], grad_fn=<SelectBackward>)
# 411
# tensor([0.0610], grad_fn=<SelectBackward>)
# 412
# tensor([0.0610], grad_fn=<SelectBackward>)
# 413
# tensor([0.0610], grad_fn=<SelectBackward>)
# 414
# tensor([0.0610], grad_fn=<SelectBackward>)
# 415
# tensor([0.0611], grad_fn=<SelectBackward>)
# 416
# tensor([0.0610], grad_fn=<SelectBackward>)
# 417
# tensor([0.0610], grad_fn=<SelectBackward>)
# 418
# tensor([0.0610], grad_fn=<SelectBackward>)
# 419
# tensor([0.0610], grad_fn=<SelectBackward>)
# 420
# tensor([0.0610], grad_fn=<SelectBackward>)
# 421
# tensor([0.0610], grad_fn=<SelectBackward>)
# 422
# tensor([0.0610], grad_fn=<SelectBackward>)
# 423
# tensor([0.0610], grad_fn=<SelectBackward>)
# 424
# tensor([0.0611], grad_fn=<SelectBackward>)
# 425
# tensor([0.0614], grad_fn=<SelectBackward>)
# 426
# tensor([0.0610], grad_fn=<SelectBackward>)
# 427
# tensor([0.0610], grad_fn=<SelectBackward>)
# 428
# tensor([0.0612], grad_fn=<SelectBackward>)
# 429
# tensor([0.0610], grad_fn=<SelectBackward>)
# 430
# tensor([0.0610], grad_fn=<SelectBackward>)
# 431
# tensor([0.0610], grad_fn=<SelectBackward>)
# 432
# tensor([0.0610], grad_fn=<SelectBackward>)
# 433
# tensor([0.0610], grad_fn=<SelectBackward>)
# 434
# tensor([0.0611], grad_fn=<SelectBackward>)
# 435
# tensor([0.0610], grad_fn=<SelectBackward>)
# 436
# tensor([0.0610], grad_fn=<SelectBackward>)
# 437
# tensor([0.0612], grad_fn=<SelectBackward>)
# 438
# tensor([0.0611], grad_fn=<SelectBackward>)
# 439
# tensor([0.0610], grad_fn=<SelectBackward>)
# 440
# tensor([0.0610], grad_fn=<SelectBackward>)
# 441
# tensor([0.0615], grad_fn=<SelectBackward>)
# 442
# tensor([0.0610], grad_fn=<SelectBackward>)
# 443
# tensor([0.0620], grad_fn=<SelectBackward>)
# 444
# tensor([0.0610], grad_fn=<SelectBackward>)
# 445
# tensor([0.0610], grad_fn=<SelectBackward>)
# 446
# tensor([0.0610], grad_fn=<SelectBackward>)
# 447
# tensor([0.0610], grad_fn=<SelectBackward>)
# 448
# tensor([0.0612], grad_fn=<SelectBackward>)
# 449
# tensor([0.0610], grad_fn=<SelectBackward>)
# 450
# tensor([0.0610], grad_fn=<SelectBackward>)
# 451
# tensor([0.0610], grad_fn=<SelectBackward>)
# 452
# tensor([0.0610], grad_fn=<SelectBackward>)
# 453
# tensor([0.0618], grad_fn=<SelectBackward>)
# 454
# tensor([0.0610], grad_fn=<SelectBackward>)
# 455
# tensor([0.0610], grad_fn=<SelectBackward>)
# 456
# tensor([0.0623], grad_fn=<SelectBackward>)
# 457
# tensor([0.0610], grad_fn=<SelectBackward>)
# 458
# tensor([0.0614], grad_fn=<SelectBackward>)
# 459
# tensor([0.0610], grad_fn=<SelectBackward>)
# 460
# tensor([0.0610], grad_fn=<SelectBackward>)
# 461
# tensor([0.0610], grad_fn=<SelectBackward>)
# 462
# tensor([0.0610], grad_fn=<SelectBackward>)
# 463
# tensor([0.0615], grad_fn=<SelectBackward>)
# 464
# tensor([0.0614], grad_fn=<SelectBackward>)
# 465
# tensor([0.0610], grad_fn=<SelectBackward>)
# 466
# tensor([0.0610], grad_fn=<SelectBackward>)
# 467
# tensor([0.0610], grad_fn=<SelectBackward>)
# 468
# tensor([0.0610], grad_fn=<SelectBackward>)
# 469
# tensor([0.0615], grad_fn=<SelectBackward>)
# 470
# tensor([0.0620], grad_fn=<SelectBackward>)
# 471
# tensor([0.0610], grad_fn=<SelectBackward>)
# 472
# tensor([0.0610], grad_fn=<SelectBackward>)
# 473
# tensor([0.0610], grad_fn=<SelectBackward>)
# 474
# tensor([0.0614], grad_fn=<SelectBackward>)
# 475
# tensor([0.0610], grad_fn=<SelectBackward>)
# 476
# tensor([0.0610], grad_fn=<SelectBackward>)
# 477
# tensor([0.0610], grad_fn=<SelectBackward>)
# 478
# tensor([0.0610], grad_fn=<SelectBackward>)
# 479
# tensor([0.0611], grad_fn=<SelectBackward>)
# 480
# tensor([0.0611], grad_fn=<SelectBackward>)
# 481
# tensor([0.0615], grad_fn=<SelectBackward>)
# 482
# tensor([0.0613], grad_fn=<SelectBackward>)
# 483
# tensor([0.0610], grad_fn=<SelectBackward>)
# 484
# tensor([0.0617], grad_fn=<SelectBackward>)
# 485
# tensor([0.0629], grad_fn=<SelectBackward>)
# 486
# tensor([0.0623], grad_fn=<SelectBackward>)
# 487
# tensor([0.0610], grad_fn=<SelectBackward>)
# 488
# tensor([0.0610], grad_fn=<SelectBackward>)
# 489
# tensor([0.0610], grad_fn=<SelectBackward>)
# 490
# tensor([0.0610], grad_fn=<SelectBackward>)
# 491
# tensor([0.0610], grad_fn=<SelectBackward>)
# 492
# tensor([0.0610], grad_fn=<SelectBackward>)
# 493
# tensor([0.0610], grad_fn=<SelectBackward>)
# 494
# tensor([0.0624], grad_fn=<SelectBackward>)
# 495
# tensor([0.0616], grad_fn=<SelectBackward>)
# 496
# tensor([0.0612], grad_fn=<SelectBackward>)
# 497
# tensor([0.0610], grad_fn=<SelectBackward>)
# 498
# tensor([0.0614], grad_fn=<SelectBackward>)
# 499
# tensor([0.0618], grad_fn=<SelectBackward>)
# 500
# tensor([0.0629], grad_fn=<SelectBackward>)
# 501
# tensor([0.0610], grad_fn=<SelectBackward>)
# 502
# tensor([0.0612], grad_fn=<SelectBackward>)
# 503
# tensor([0.0610], grad_fn=<SelectBackward>)
# 504
# tensor([0.0614], grad_fn=<SelectBackward>)
# 505
# tensor([0.0620], grad_fn=<SelectBackward>)
# 506
# tensor([0.0610], grad_fn=<SelectBackward>)
# 507
# tensor([0.0610], grad_fn=<SelectBackward>)
# 508
# tensor([0.0614], grad_fn=<SelectBackward>)
# 509
# tensor([0.0614], grad_fn=<SelectBackward>)
# 510
# tensor([0.0612], grad_fn=<SelectBackward>)
# 511
# tensor([0.0615], grad_fn=<SelectBackward>)
# 512
# tensor([0.0610], grad_fn=<SelectBackward>)
# 513
# tensor([0.0630], grad_fn=<SelectBackward>)
# 514
# tensor([0.0610], grad_fn=<SelectBackward>)
# 515
# tensor([0.0611], grad_fn=<SelectBackward>)
# 516
# tensor([0.0636], grad_fn=<SelectBackward>)
# 517
# tensor([0.0610], grad_fn=<SelectBackward>)
# 518
# tensor([0.0630], grad_fn=<SelectBackward>)
# 519
# tensor([0.0619], grad_fn=<SelectBackward>)
# 520
# tensor([0.0610], grad_fn=<SelectBackward>)
# 521
# tensor([0.0623], grad_fn=<SelectBackward>)
# 522
# tensor([0.0611], grad_fn=<SelectBackward>)
# 523
# tensor([0.0632], grad_fn=<SelectBackward>)
# 524
# tensor([0.0643], grad_fn=<SelectBackward>)
# 525
# tensor([0.0610], grad_fn=<SelectBackward>)
# 526
# tensor([0.0610], grad_fn=<SelectBackward>)
# 527
# tensor([0.0613], grad_fn=<SelectBackward>)
# 528
# tensor([0.0610], grad_fn=<SelectBackward>)
# 529
# tensor([0.0622], grad_fn=<SelectBackward>)
# 530
# tensor([0.0611], grad_fn=<SelectBackward>)
# 531
# tensor([0.0612], grad_fn=<SelectBackward>)
# 532
# tensor([0.0632], grad_fn=<SelectBackward>)
# 533
# tensor([0.0645], grad_fn=<SelectBackward>)
# 534
# tensor([0.0645], grad_fn=<SelectBackward>)
# 535
# tensor([0.0623], grad_fn=<SelectBackward>)
# 536
# tensor([0.0624], grad_fn=<SelectBackward>)
# 537
# tensor([0.0633], grad_fn=<SelectBackward>)
# 538
# tensor([0.0610], grad_fn=<SelectBackward>)
# 539
# tensor([0.0639], grad_fn=<SelectBackward>)
# 540
# tensor([0.0633], grad_fn=<SelectBackward>)
# 541
# tensor([0.0610], grad_fn=<SelectBackward>)
# 542
# tensor([0.0623], grad_fn=<SelectBackward>)
# 543
# tensor([0.0613], grad_fn=<SelectBackward>)
# 544
# tensor([0.0610], grad_fn=<SelectBackward>)
# 545
# tensor([0.0646], grad_fn=<SelectBackward>)
# 546
# tensor([0.0624], grad_fn=<SelectBackward>)
# 547
# tensor([0.0618], grad_fn=<SelectBackward>)
# 548
# tensor([0.0610], grad_fn=<SelectBackward>)
# 549
# tensor([0.0638], grad_fn=<SelectBackward>)
# 550
# tensor([0.0616], grad_fn=<SelectBackward>)
# 551
# tensor([0.0618], grad_fn=<SelectBackward>)
# 552
# tensor([0.0656], grad_fn=<SelectBackward>)
# 553
# tensor([0.0631], grad_fn=<SelectBackward>)
# 554
# tensor([0.0612], grad_fn=<SelectBackward>)
# 555
# tensor([0.0610], grad_fn=<SelectBackward>)
# 556
# tensor([0.0611], grad_fn=<SelectBackward>)
# 557
# tensor([0.0610], grad_fn=<SelectBackward>)
# 558
# tensor([0.0610], grad_fn=<SelectBackward>)
# 559
# tensor([0.0611], grad_fn=<SelectBackward>)
# 560
# tensor([0.0611], grad_fn=<SelectBackward>)
# 561
# tensor([0.0610], grad_fn=<SelectBackward>)
# 562
# tensor([0.0616], grad_fn=<SelectBackward>)
# 563
# tensor([0.0613], grad_fn=<SelectBackward>)
# 564
# tensor([0.0611], grad_fn=<SelectBackward>)
# 565
# tensor([0.0612], grad_fn=<SelectBackward>)
# 566
# tensor([0.0610], grad_fn=<SelectBackward>)
# 567
# tensor([0.0610], grad_fn=<SelectBackward>)
# 568
# tensor([0.0615], grad_fn=<SelectBackward>)
# 569
# tensor([0.0612], grad_fn=<SelectBackward>)
# 570
# tensor([0.0610], grad_fn=<SelectBackward>)
# 571
# tensor([0.0610], grad_fn=<SelectBackward>)
# 572
# tensor([0.0610], grad_fn=<SelectBackward>)
# 573
# tensor([0.0611], grad_fn=<SelectBackward>)
# 574
# tensor([0.0610], grad_fn=<SelectBackward>)
# 575
# tensor([0.0610], grad_fn=<SelectBackward>)
# 576
# tensor([0.0613], grad_fn=<SelectBackward>)
# 577
# tensor([0.0610], grad_fn=<SelectBackward>)
# 578
# tensor([0.0610], grad_fn=<SelectBackward>)
# 579
# tensor([0.0610], grad_fn=<SelectBackward>)
# 580
# tensor([0.0610], grad_fn=<SelectBackward>)
# 581
# tensor([0.0610], grad_fn=<SelectBackward>)
# 582
# tensor([0.0611], grad_fn=<SelectBackward>)
# 583
# tensor([0.0611], grad_fn=<SelectBackward>)
# 584
# tensor([0.0610], grad_fn=<SelectBackward>)
# 585
# tensor([0.0610], grad_fn=<SelectBackward>)
# 586
# tensor([0.0611], grad_fn=<SelectBackward>)
# 587
# tensor([0.0610], grad_fn=<SelectBackward>)
# 588
# tensor([0.0611], grad_fn=<SelectBackward>)
# 589
# tensor([0.0613], grad_fn=<SelectBackward>)
# 590
# tensor([0.0613], grad_fn=<SelectBackward>)
# 591
# tensor([0.0610], grad_fn=<SelectBackward>)
# 592
# tensor([0.0610], grad_fn=<SelectBackward>)
# 593
# tensor([0.0611], grad_fn=<SelectBackward>)
# 594
# tensor([0.0610], grad_fn=<SelectBackward>)
# 595
# tensor([0.0612], grad_fn=<SelectBackward>)
# 596
# tensor([0.0611], grad_fn=<SelectBackward>)
# 597
# tensor([0.0610], grad_fn=<SelectBackward>)
# 598
# tensor([0.0610], grad_fn=<SelectBackward>)
# 599
# tensor([0.0610], grad_fn=<SelectBackward>)
# 600
# tensor([0.0610], grad_fn=<SelectBackward>)
# 601
# tensor([0.0610], grad_fn=<SelectBackward>)
# 602
# tensor([0.0610], grad_fn=<SelectBackward>)
# 603
# tensor([0.0611], grad_fn=<SelectBackward>)
# 604
# tensor([0.0610], grad_fn=<SelectBackward>)
# 605
# tensor([0.0610], grad_fn=<SelectBackward>)
# 606
# tensor([0.0610], grad_fn=<SelectBackward>)
# 607
# tensor([0.0610], grad_fn=<SelectBackward>)
# 608
# tensor([0.0610], grad_fn=<SelectBackward>)
# 609
# tensor([0.0611], grad_fn=<SelectBackward>)
# 610
# tensor([0.0610], grad_fn=<SelectBackward>)
# 611
# tensor([0.0610], grad_fn=<SelectBackward>)
# 612
# tensor([0.0610], grad_fn=<SelectBackward>)
# 613
# tensor([0.0612], grad_fn=<SelectBackward>)
# 614
# tensor([0.0613], grad_fn=<SelectBackward>)
# 615
# tensor([0.0610], grad_fn=<SelectBackward>)
# 616
# tensor([0.0610], grad_fn=<SelectBackward>)
# 617
# tensor([0.0610], grad_fn=<SelectBackward>)
# 618
# tensor([0.0610], grad_fn=<SelectBackward>)
# 619
# tensor([0.0610], grad_fn=<SelectBackward>)
# 620
# tensor([0.0611], grad_fn=<SelectBackward>)
# 621
# tensor([0.0610], grad_fn=<SelectBackward>)
# 622
# tensor([0.0610], grad_fn=<SelectBackward>)
# 623
# tensor([0.0610], grad_fn=<SelectBackward>)
# 624
# tensor([0.0612], grad_fn=<SelectBackward>)
# 625
# tensor([0.0615], grad_fn=<SelectBackward>)
# 626
# tensor([0.0610], grad_fn=<SelectBackward>)
# 627
# tensor([0.0610], grad_fn=<SelectBackward>)
# 628
# tensor([0.0610], grad_fn=<SelectBackward>)
# 629
# tensor([0.0610], grad_fn=<SelectBackward>)
# 630
# tensor([0.0610], grad_fn=<SelectBackward>)
# 631
# tensor([0.0610], grad_fn=<SelectBackward>)
# 632
# tensor([0.0610], grad_fn=<SelectBackward>)
# 633
# tensor([0.0611], grad_fn=<SelectBackward>)
# 634
# tensor([0.0610], grad_fn=<SelectBackward>)
# 635
# tensor([0.0610], grad_fn=<SelectBackward>)
# 636
# tensor([0.0610], grad_fn=<SelectBackward>)
# 637
# tensor([0.0610], grad_fn=<SelectBackward>)
# 638
# tensor([0.0612], grad_fn=<SelectBackward>)
# 639
# tensor([0.0611], grad_fn=<SelectBackward>)
# 640
# tensor([0.0610], grad_fn=<SelectBackward>)
# 641
# tensor([0.0610], grad_fn=<SelectBackward>)
# 642
# tensor([0.0611], grad_fn=<SelectBackward>)
# 643
# tensor([0.0612], grad_fn=<SelectBackward>)
# 644
# tensor([0.0611], grad_fn=<SelectBackward>)
# 645
# tensor([0.0611], grad_fn=<SelectBackward>)
# 646
# tensor([0.0610], grad_fn=<SelectBackward>)
# 647
# tensor([0.0610], grad_fn=<SelectBackward>)
# 648
# tensor([0.0610], grad_fn=<SelectBackward>)
# 649
# tensor([0.0612], grad_fn=<SelectBackward>)
# 650
# tensor([0.0610], grad_fn=<SelectBackward>)
# 651
# tensor([0.0611], grad_fn=<SelectBackward>)
# 652
# tensor([0.0610], grad_fn=<SelectBackward>)
# 653
# tensor([0.0610], grad_fn=<SelectBackward>)
# 654
# tensor([0.0610], grad_fn=<SelectBackward>)
# 655
# tensor([0.0610], grad_fn=<SelectBackward>)
# 656
# tensor([0.0614], grad_fn=<SelectBackward>)
# 657
# tensor([0.0610], grad_fn=<SelectBackward>)
# 658
# tensor([0.0610], grad_fn=<SelectBackward>)
# 659
# tensor([0.0610], grad_fn=<SelectBackward>)
# 660
# tensor([0.0611], grad_fn=<SelectBackward>)
# 661
# tensor([0.0610], grad_fn=<SelectBackward>)
# 662
# tensor([0.0610], grad_fn=<SelectBackward>)
# 663
# tensor([0.0610], grad_fn=<SelectBackward>)
# 664
# tensor([0.0610], grad_fn=<SelectBackward>)
# 665
# tensor([0.0614], grad_fn=<SelectBackward>)
# 666
# tensor([0.0610], grad_fn=<SelectBackward>)
# 667
# tensor([0.0610], grad_fn=<SelectBackward>)
# 668
# tensor([0.0610], grad_fn=<SelectBackward>)
# 669
# tensor([0.0610], grad_fn=<SelectBackward>)
# 670
# tensor([0.0610], grad_fn=<SelectBackward>)
# 671
# tensor([0.0611], grad_fn=<SelectBackward>)
# 672
# tensor([0.0610], grad_fn=<SelectBackward>)
# 673
# tensor([0.0610], grad_fn=<SelectBackward>)
# 674
# tensor([0.0610], grad_fn=<SelectBackward>)
# 675
# tensor([0.0610], grad_fn=<SelectBackward>)
# 676
# tensor([0.0610], grad_fn=<SelectBackward>)
# 677
# tensor([0.0612], grad_fn=<SelectBackward>)
# 678
# tensor([0.0610], grad_fn=<SelectBackward>)
# 679
# tensor([0.0632], grad_fn=<SelectBackward>)
# 680
# tensor([0.0634], grad_fn=<SelectBackward>)
# 681
# tensor([0.0610], grad_fn=<SelectBackward>)
# 682
# tensor([0.0610], grad_fn=<SelectBackward>)
# 683
# tensor([0.0610], grad_fn=<SelectBackward>)
# 684
# tensor([0.0610], grad_fn=<SelectBackward>)
# 685
# tensor([0.0611], grad_fn=<SelectBackward>)
# 686
# tensor([0.0610], grad_fn=<SelectBackward>)
# 687
# tensor([0.0610], grad_fn=<SelectBackward>)
# 688
# tensor([0.0627], grad_fn=<SelectBackward>)
# 689
# tensor([0.0613], grad_fn=<SelectBackward>)
# 690
# tensor([0.0617], grad_fn=<SelectBackward>)
# 691
# tensor([0.0611], grad_fn=<SelectBackward>)
# 692
# tensor([0.0610], grad_fn=<SelectBackward>)
# 693
# tensor([0.0626], grad_fn=<SelectBackward>)
# 694
# tensor([0.0610], grad_fn=<SelectBackward>)
# 695
# tensor([0.0612], grad_fn=<SelectBackward>)
# 696
# tensor([0.0611], grad_fn=<SelectBackward>)
# 697
# tensor([0.0610], grad_fn=<SelectBackward>)
# 698
# tensor([0.0610], grad_fn=<SelectBackward>)
# 699
# tensor([0.0610], grad_fn=<SelectBackward>)
# 700
# tensor([0.0611], grad_fn=<SelectBackward>)
# 701
# tensor([0.0610], grad_fn=<SelectBackward>)
# 702
# tensor([0.0610], grad_fn=<SelectBackward>)
# 703
# tensor([0.0612], grad_fn=<SelectBackward>)
# 704
# tensor([0.0610], grad_fn=<SelectBackward>)
# 705
# tensor([0.0611], grad_fn=<SelectBackward>)
# 706
# tensor([0.0610], grad_fn=<SelectBackward>)
# 707
# tensor([0.0610], grad_fn=<SelectBackward>)
# 708
# tensor([0.0610], grad_fn=<SelectBackward>)
# 709
# tensor([0.0610], grad_fn=<SelectBackward>)
# 710
# tensor([0.0618], grad_fn=<SelectBackward>)
# 711
# tensor([0.0614], grad_fn=<SelectBackward>)
# 712
# tensor([0.0610], grad_fn=<SelectBackward>)
# 713
# tensor([0.0618], grad_fn=<SelectBackward>)
# 714
# tensor([0.0620], grad_fn=<SelectBackward>)
# 715
# tensor([0.0640], grad_fn=<SelectBackward>)
# 716
# tensor([0.0610], grad_fn=<SelectBackward>)
# 717
# tensor([0.0613], grad_fn=<SelectBackward>)
# 718
# tensor([0.0629], grad_fn=<SelectBackward>)
# 719
# tensor([0.0630], grad_fn=<SelectBackward>)
# 720
# tensor([0.0610], grad_fn=<SelectBackward>)
# 721
# tensor([0.0621], grad_fn=<SelectBackward>)
# 722
# tensor([0.0610], grad_fn=<SelectBackward>)
# 723
# tensor([0.0610], grad_fn=<SelectBackward>)
# 724
# tensor([0.0610], grad_fn=<SelectBackward>)
# 725
# tensor([0.0610], grad_fn=<SelectBackward>)
# 726
# tensor([0.0611], grad_fn=<SelectBackward>)
# 727
# tensor([0.0613], grad_fn=<SelectBackward>)
# 728
# tensor([0.0623], grad_fn=<SelectBackward>)
# 729
# tensor([0.0624], grad_fn=<SelectBackward>)
# 730
# tensor([0.0619], grad_fn=<SelectBackward>)
# 731
# tensor([0.0611], grad_fn=<SelectBackward>)
# 732
# tensor([0.0612], grad_fn=<SelectBackward>)
# 733
# tensor([0.0610], grad_fn=<SelectBackward>)
# 734
# tensor([0.0610], grad_fn=<SelectBackward>)
# 735
# tensor([0.0611], grad_fn=<SelectBackward>)
# 736
# tensor([0.0611], grad_fn=<SelectBackward>)
# 737
# tensor([0.0610], grad_fn=<SelectBackward>)
# 738
# tensor([0.0621], grad_fn=<SelectBackward>)
# 739
# tensor([0.0610], grad_fn=<SelectBackward>)
# 740
# tensor([0.0626], grad_fn=<SelectBackward>)
# 741
# tensor([0.0610], grad_fn=<SelectBackward>)
# 742
# tensor([0.0612], grad_fn=<SelectBackward>)
# 743
# tensor([0.0610], grad_fn=<SelectBackward>)
# 744
# tensor([0.0618], grad_fn=<SelectBackward>)
# 745
# tensor([0.0610], grad_fn=<SelectBackward>)
# 746
# tensor([0.0616], grad_fn=<SelectBackward>)
# 747
# tensor([0.0610], grad_fn=<SelectBackward>)
# 748
# tensor([0.0618], grad_fn=<SelectBackward>)
# 749
# tensor([0.0623], grad_fn=<SelectBackward>)
# 750
# tensor([0.0622], grad_fn=<SelectBackward>)
# 751
# tensor([0.0617], grad_fn=<SelectBackward>)
# 752
# tensor([0.0641], grad_fn=<SelectBackward>)
# 753
# tensor([0.0623], grad_fn=<SelectBackward>)
# 754
# tensor([0.0634], grad_fn=<SelectBackward>)
# 755
# tensor([0.0610], grad_fn=<SelectBackward>)
# 756
# tensor([0.0619], grad_fn=<SelectBackward>)
# 757
# tensor([0.0615], grad_fn=<SelectBackward>)
# 758
# tensor([0.0620], grad_fn=<SelectBackward>)
# 759
# tensor([0.0617], grad_fn=<SelectBackward>)
# 760
# tensor([0.0621], grad_fn=<SelectBackward>)
# 761
# tensor([0.0610], grad_fn=<SelectBackward>)
# 762
# tensor([0.0611], grad_fn=<SelectBackward>)
# 763
# tensor([0.0627], grad_fn=<SelectBackward>)
# 764
# tensor([0.0636], grad_fn=<SelectBackward>)
# 765
# tensor([0.0630], grad_fn=<SelectBackward>)
# 766
# tensor([0.0612], grad_fn=<SelectBackward>)
# 767
# tensor([0.0612], grad_fn=<SelectBackward>)
# 768
# tensor([0.0624], grad_fn=<SelectBackward>)
# 769
# tensor([0.0637], grad_fn=<SelectBackward>)
# 770
# tensor([0.0623], grad_fn=<SelectBackward>)
# 771
# tensor([0.0621], grad_fn=<SelectBackward>)
# 772
# tensor([0.0627], grad_fn=<SelectBackward>)
# 773
# tensor([0.0621], grad_fn=<SelectBackward>)
# 774
# tensor([0.0617], grad_fn=<SelectBackward>)
# 775
# tensor([0.0625], grad_fn=<SelectBackward>)
# 776
# tensor([0.0616], grad_fn=<SelectBackward>)
# 777
# tensor([0.0611], grad_fn=<SelectBackward>)
# 778
# tensor([0.0619], grad_fn=<SelectBackward>)
# 779
# tensor([0.0613], grad_fn=<SelectBackward>)
# 780
# tensor([0.0619], grad_fn=<SelectBackward>)
# 781
# tensor([0.0627], grad_fn=<SelectBackward>)
# 782
# tensor([0.0618], grad_fn=<SelectBackward>)
# 783
# tensor([0.0618], grad_fn=<SelectBackward>)
# 784
# tensor([0.0616], grad_fn=<SelectBackward>)
# 785
# tensor([0.0645], grad_fn=<SelectBackward>)
# 786
# tensor([0.0627], grad_fn=<SelectBackward>)
# 787
# tensor([0.0633], grad_fn=<SelectBackward>)
# 788
# tensor([0.0634], grad_fn=<SelectBackward>)
# 789
# tensor([0.0619], grad_fn=<SelectBackward>)
# 790
# tensor([0.0633], grad_fn=<SelectBackward>)
# 791
# tensor([0.0630], grad_fn=<SelectBackward>)
# 792
# tensor([0.0640], grad_fn=<SelectBackward>)
# 793
# tensor([0.0610], grad_fn=<SelectBackward>)
# 794
# tensor([0.0614], grad_fn=<SelectBackward>)
# 795
# tensor([0.0643], grad_fn=<SelectBackward>)
# 796
# tensor([0.0611], grad_fn=<SelectBackward>)
# 797
# tensor([0.0639], grad_fn=<SelectBackward>)
# 798
# tensor([0.0647], grad_fn=<SelectBackward>)
# 799
# tensor([0.0634], grad_fn=<SelectBackward>)
# 800
# tensor([0.0633], grad_fn=<SelectBackward>)
# 801
# tensor([0.0622], grad_fn=<SelectBackward>)
# 802
# tensor([0.0610], grad_fn=<SelectBackward>)
# 803
# tensor([0.0625], grad_fn=<SelectBackward>)
# 804
# tensor([0.0629], grad_fn=<SelectBackward>)
# 805
# tensor([0.0630], grad_fn=<SelectBackward>)
# 806
# tensor([0.0636], grad_fn=<SelectBackward>)
# 807
# tensor([0.0636], grad_fn=<SelectBackward>)
# 808
# tensor([0.0633], grad_fn=<SelectBackward>)
# 809
# tensor([0.0640], grad_fn=<SelectBackward>)
# 810
# tensor([0.0645], grad_fn=<SelectBackward>)
# 811
# tensor([0.0631], grad_fn=<SelectBackward>)
# 812
# tensor([0.0661], grad_fn=<SelectBackward>)
# 813
# tensor([0.0652], grad_fn=<SelectBackward>)
# 814
# tensor([0.0617], grad_fn=<SelectBackward>)
# 815
# tensor([0.0610], grad_fn=<SelectBackward>)
# 816
# tensor([0.0611], grad_fn=<SelectBackward>)
# 817
# tensor([0.0617], grad_fn=<SelectBackward>)
# 818
# tensor([0.0626], grad_fn=<SelectBackward>)
# 819
# tensor([0.0610], grad_fn=<SelectBackward>)
# 820
# tensor([0.0613], grad_fn=<SelectBackward>)
# 821
# tensor([0.0615], grad_fn=<SelectBackward>)
# 822
# tensor([0.0611], grad_fn=<SelectBackward>)
# 823
# tensor([0.0610], grad_fn=<SelectBackward>)
# 824
# tensor([0.0614], grad_fn=<SelectBackward>)
# 825
# tensor([0.0611], grad_fn=<SelectBackward>)
# 826
# tensor([0.0610], grad_fn=<SelectBackward>)
# 827
# tensor([0.0619], grad_fn=<SelectBackward>)
# 828
# tensor([0.0612], grad_fn=<SelectBackward>)
# 829
# tensor([0.0610], grad_fn=<SelectBackward>)
# 830
# tensor([0.0612], grad_fn=<SelectBackward>)
# 831
# tensor([0.0610], grad_fn=<SelectBackward>)
# 832
# tensor([0.0610], grad_fn=<SelectBackward>)
# 833
# tensor([0.0610], grad_fn=<SelectBackward>)
# 834
# tensor([0.0611], grad_fn=<SelectBackward>)
# 835
# tensor([0.0610], grad_fn=<SelectBackward>)
# 836
# tensor([0.0611], grad_fn=<SelectBackward>)
# 837
# tensor([0.0610], grad_fn=<SelectBackward>)
# 838
# tensor([0.0610], grad_fn=<SelectBackward>)
# 839
# tensor([0.0612], grad_fn=<SelectBackward>)
# 840
# tensor([0.0610], grad_fn=<SelectBackward>)
# 841
# tensor([0.0611], grad_fn=<SelectBackward>)
# 842
# tensor([0.0610], grad_fn=<SelectBackward>)
# 843
# tensor([0.0611], grad_fn=<SelectBackward>)
# 844
# tensor([0.0611], grad_fn=<SelectBackward>)
# 845
# tensor([0.0610], grad_fn=<SelectBackward>)
# 846
# tensor([0.0610], grad_fn=<SelectBackward>)
# 847
# tensor([0.0612], grad_fn=<SelectBackward>)
# 848
# tensor([0.0611], grad_fn=<SelectBackward>)
# 849
# tensor([0.0610], grad_fn=<SelectBackward>)
# 850
# tensor([0.0610], grad_fn=<SelectBackward>)
# 851
# tensor([0.0612], grad_fn=<SelectBackward>)
# 852
# tensor([0.0610], grad_fn=<SelectBackward>)
# 853
# tensor([0.0610], grad_fn=<SelectBackward>)
# 854
# tensor([0.0611], grad_fn=<SelectBackward>)
# 855
# tensor([0.0610], grad_fn=<SelectBackward>)
# 856
# tensor([0.0610], grad_fn=<SelectBackward>)
# 857
# tensor([0.0610], grad_fn=<SelectBackward>)
# 858
# tensor([0.0610], grad_fn=<SelectBackward>)
# 859
# tensor([0.0611], grad_fn=<SelectBackward>)
# 860
# tensor([0.0610], grad_fn=<SelectBackward>)
# 861
# tensor([0.0610], grad_fn=<SelectBackward>)
# 862
# tensor([0.0614], grad_fn=<SelectBackward>)
# 863
# tensor([0.0611], grad_fn=<SelectBackward>)
# 864
# tensor([0.0610], grad_fn=<SelectBackward>)
# 865
# tensor([0.0610], grad_fn=<SelectBackward>)
# 866
# tensor([0.0610], grad_fn=<SelectBackward>)
# 867
# tensor([0.0610], grad_fn=<SelectBackward>)
# 868
# tensor([0.0612], grad_fn=<SelectBackward>)
# 869
# tensor([0.0610], grad_fn=<SelectBackward>)
# 870
# tensor([0.0610], grad_fn=<SelectBackward>)
# 871
# tensor([0.0610], grad_fn=<SelectBackward>)
# 872
# tensor([0.0611], grad_fn=<SelectBackward>)
# 873
# tensor([0.0610], grad_fn=<SelectBackward>)
# 874
# tensor([0.0610], grad_fn=<SelectBackward>)
# 875
# tensor([0.0610], grad_fn=<SelectBackward>)
# 876
# tensor([0.0610], grad_fn=<SelectBackward>)
# 877
# tensor([0.0610], grad_fn=<SelectBackward>)
# 878
# tensor([0.0610], grad_fn=<SelectBackward>)
# 879
# tensor([0.0610], grad_fn=<SelectBackward>)
# 880
# tensor([0.0612], grad_fn=<SelectBackward>)
# 881
# tensor([0.0610], grad_fn=<SelectBackward>)
# 882
# tensor([0.0610], grad_fn=<SelectBackward>)
# 883
# tensor([0.0611], grad_fn=<SelectBackward>)
# 884
# tensor([0.0610], grad_fn=<SelectBackward>)
# 885
# tensor([0.0610], grad_fn=<SelectBackward>)
# 886
# tensor([0.0611], grad_fn=<SelectBackward>)
# 887
# tensor([0.0610], grad_fn=<SelectBackward>)
# 888
# tensor([0.0610], grad_fn=<SelectBackward>)
# 889
# tensor([0.0610], grad_fn=<SelectBackward>)
# 890
# tensor([0.0610], grad_fn=<SelectBackward>)
# 891
# tensor([0.0610], grad_fn=<SelectBackward>)
# 892
# tensor([0.0610], grad_fn=<SelectBackward>)
# 893
# tensor([0.0610], grad_fn=<SelectBackward>)
# 894
# tensor([0.0610], grad_fn=<SelectBackward>)
# 895
# tensor([0.0610], grad_fn=<SelectBackward>)
# 896
# tensor([0.0610], grad_fn=<SelectBackward>)
# 897
# tensor([0.0610], grad_fn=<SelectBackward>)
# 898
# tensor([0.0610], grad_fn=<SelectBackward>)
# 899
# tensor([0.0610], grad_fn=<SelectBackward>)
# 900
# tensor([0.0611], grad_fn=<SelectBackward>)
# 901
# tensor([0.0610], grad_fn=<SelectBackward>)
# 902
# tensor([0.0610], grad_fn=<SelectBackward>)
# 903
# tensor([0.0610], grad_fn=<SelectBackward>)
# 904
# tensor([0.0610], grad_fn=<SelectBackward>)
# 905
# tensor([0.0610], grad_fn=<SelectBackward>)
# 906
# tensor([0.0610], grad_fn=<SelectBackward>)
# 907
# tensor([0.0610], grad_fn=<SelectBackward>)
# 908
# tensor([0.0621], grad_fn=<SelectBackward>)
# 909
# tensor([0.0610], grad_fn=<SelectBackward>)
# 910
# tensor([0.0610], grad_fn=<SelectBackward>)
# 911
# tensor([0.0612], grad_fn=<SelectBackward>)
# 912
# tensor([0.0610], grad_fn=<SelectBackward>)
# 913
# tensor([0.0610], grad_fn=<SelectBackward>)
# 914
# tensor([0.0610], grad_fn=<SelectBackward>)
# 915
# tensor([0.0612], grad_fn=<SelectBackward>)
# 916
# tensor([0.0611], grad_fn=<SelectBackward>)
# 917
# tensor([0.0611], grad_fn=<SelectBackward>)
# 918
# tensor([0.0610], grad_fn=<SelectBackward>)
# 919
# tensor([0.0610], grad_fn=<SelectBackward>)
# 920
# tensor([0.0611], grad_fn=<SelectBackward>)
# 921
# tensor([0.0612], grad_fn=<SelectBackward>)
# 922
# tensor([0.0610], grad_fn=<SelectBackward>)
# 923
# tensor([0.0615], grad_fn=<SelectBackward>)
# 924
# tensor([0.0610], grad_fn=<SelectBackward>)
# 925
# tensor([0.0618], grad_fn=<SelectBackward>)
# 926
# tensor([0.0610], grad_fn=<SelectBackward>)
# 927
# tensor([0.0610], grad_fn=<SelectBackward>)
# 928
# tensor([0.0614], grad_fn=<SelectBackward>)
# 929
# tensor([0.0611], grad_fn=<SelectBackward>)
# 930
# tensor([0.0620], grad_fn=<SelectBackward>)
# 931
# tensor([0.0610], grad_fn=<SelectBackward>)
# 932
# tensor([0.0610], grad_fn=<SelectBackward>)
# 933
# tensor([0.0613], grad_fn=<SelectBackward>)
# 934
# tensor([0.0610], grad_fn=<SelectBackward>)
# 935
# tensor([0.0623], grad_fn=<SelectBackward>)
# 936
# tensor([0.0610], grad_fn=<SelectBackward>)
# 937
# tensor([0.0610], grad_fn=<SelectBackward>)
# 938
# tensor([0.0610], grad_fn=<SelectBackward>)
# 939
# tensor([0.0610], grad_fn=<SelectBackward>)
# 940
# tensor([0.0610], grad_fn=<SelectBackward>)
# 941
# tensor([0.0610], grad_fn=<SelectBackward>)
# 942
# tensor([0.0621], grad_fn=<SelectBackward>)
# 943
# tensor([0.0610], grad_fn=<SelectBackward>)
# 944
# tensor([0.0610], grad_fn=<SelectBackward>)
# 945
# tensor([0.0610], grad_fn=<SelectBackward>)
# 946
# tensor([0.0610], grad_fn=<SelectBackward>)
# 947
# tensor([0.0610], grad_fn=<SelectBackward>)
# 948
# tensor([0.0610], grad_fn=<SelectBackward>)
# 949
# tensor([0.0611], grad_fn=<SelectBackward>)
# 950
# tensor([0.0613], grad_fn=<SelectBackward>)
# 951
# tensor([0.0610], grad_fn=<SelectBackward>)
# 952
# tensor([0.0611], grad_fn=<SelectBackward>)
# 953
# tensor([0.0610], grad_fn=<SelectBackward>)
# 954
# tensor([0.0610], grad_fn=<SelectBackward>)
# 955
# tensor([0.0612], grad_fn=<SelectBackward>)
# 956
# tensor([0.0610], grad_fn=<SelectBackward>)
# 957
# tensor([0.0613], grad_fn=<SelectBackward>)
# 958
# tensor([0.0610], grad_fn=<SelectBackward>)
# 959
# tensor([0.0611], grad_fn=<SelectBackward>)
# 960
# tensor([0.0611], grad_fn=<SelectBackward>)
# 961
# tensor([0.0610], grad_fn=<SelectBackward>)
# 962
# tensor([0.0610], grad_fn=<SelectBackward>)
# 963
# tensor([0.0610], grad_fn=<SelectBackward>)
# 964
# tensor([0.0617], grad_fn=<SelectBackward>)
# 965
# tensor([0.0612], grad_fn=<SelectBackward>)
# 966
# tensor([0.0612], grad_fn=<SelectBackward>)
# 967
# tensor([0.0610], grad_fn=<SelectBackward>)
# 968
# tensor([0.0610], grad_fn=<SelectBackward>)
# 969
# tensor([0.0613], grad_fn=<SelectBackward>)
# 970
# tensor([0.0612], grad_fn=<SelectBackward>)
# 971
# tensor([0.0610], grad_fn=<SelectBackward>)
# 972
# tensor([0.0611], grad_fn=<SelectBackward>)
# 973
# tensor([0.0610], grad_fn=<SelectBackward>)
# 974
# tensor([0.0610], grad_fn=<SelectBackward>)
# 975
# tensor([0.0621], grad_fn=<SelectBackward>)
# 976
# tensor([0.0610], grad_fn=<SelectBackward>)
# 977
# tensor([0.0611], grad_fn=<SelectBackward>)
# 978
# tensor([0.0618], grad_fn=<SelectBackward>)
# 979
# tensor([0.0611], grad_fn=<SelectBackward>)
# 980
# tensor([0.0611], grad_fn=<SelectBackward>)
# 981
# tensor([0.0611], grad_fn=<SelectBackward>)
# 982
# tensor([0.0613], grad_fn=<SelectBackward>)
# 983
# tensor([0.0613], grad_fn=<SelectBackward>)
# 984
# tensor([0.0620], grad_fn=<SelectBackward>)
# 985
# tensor([0.0616], grad_fn=<SelectBackward>)
# 986
# tensor([0.0630], grad_fn=<SelectBackward>)
# 987
# tensor([0.0610], grad_fn=<SelectBackward>)
# 988
# tensor([0.0610], grad_fn=<SelectBackward>)
# 989
# tensor([0.0620], grad_fn=<SelectBackward>)
# 990
# tensor([0.0617], grad_fn=<SelectBackward>)
# 991
# tensor([0.0616], grad_fn=<SelectBackward>)
# 992
# tensor([0.0611], grad_fn=<SelectBackward>)
# 993
# tensor([0.0616], grad_fn=<SelectBackward>)
# 994
# tensor([0.0610], grad_fn=<SelectBackward>)
# 995
# tensor([0.0619], grad_fn=<SelectBackward>)
# 996
# tensor([0.0611], grad_fn=<SelectBackward>)
# 997
# tensor([0.0611], grad_fn=<SelectBackward>)
# 998
# tensor([0.0611], grad_fn=<SelectBackward>)
# 999
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1000
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1001
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1002
# tensor([0.0618], grad_fn=<SelectBackward>)
# 1003
# tensor([0.0621], grad_fn=<SelectBackward>)
# 1004
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1005
# tensor([0.0613], grad_fn=<SelectBackward>)
# 1006
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1007
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1008
# tensor([0.0624], grad_fn=<SelectBackward>)
# 1009
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1010
# tensor([0.0616], grad_fn=<SelectBackward>)
# 1011
# tensor([0.0626], grad_fn=<SelectBackward>)
# 1012
# tensor([0.0612], grad_fn=<SelectBackward>)
# 1013
# tensor([0.0612], grad_fn=<SelectBackward>)
# 1014
# tensor([0.0624], grad_fn=<SelectBackward>)
# 1015
# tensor([0.0621], grad_fn=<SelectBackward>)
# 1016
# tensor([0.0620], grad_fn=<SelectBackward>)
# 1017
# tensor([0.0629], grad_fn=<SelectBackward>)
# 1018
# tensor([0.0618], grad_fn=<SelectBackward>)
# 1019
# tensor([0.0621], grad_fn=<SelectBackward>)
# 1020
# tensor([0.0615], grad_fn=<SelectBackward>)
# 1021
# ...
# 1290
# tensor([0.0622], grad_fn=<SelectBackward>)
# 1291
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1292
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1293
# tensor([0.0638], grad_fn=<SelectBackward>)
# 1294
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1295
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1296
# tensor([0.0636], grad_fn=<SelectBackward>)
# 1297
# tensor([0.0615], grad_fn=<SelectBackward>)
# 1298
# tensor([0.0620], grad_fn=<SelectBackward>)
# 1299
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1300
# tensor([0.0626], grad_fn=<SelectBackward>)
# 1301
# tensor([0.0614], grad_fn=<SelectBackward>)
# 1302
# tensor([0.0622], grad_fn=<SelectBackward>)
# 1303
# tensor([0.0623], grad_fn=<SelectBackward>)
# 1304
# tensor([0.0620], grad_fn=<SelectBackward>)
# 1305
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1306
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1307
# tensor([0.0618], grad_fn=<SelectBackward>)
# 1308
# tensor([0.0629], grad_fn=<SelectBackward>)
# 1309
# tensor([0.0613], grad_fn=<SelectBackward>)
# 1310
# tensor([0.0631], grad_fn=<SelectBackward>)
# 1311
# tensor([0.0628], grad_fn=<SelectBackward>)
# 1312
# tensor([0.0622], grad_fn=<SelectBackward>)
# 1313
# tensor([0.0612], grad_fn=<SelectBackward>)
# 1314
# tensor([0.0619], grad_fn=<SelectBackward>)
# 1315
# tensor([0.0612], grad_fn=<SelectBackward>)
# 1316
# tensor([0.0612], grad_fn=<SelectBackward>)
# 1317
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1318
# tensor([0.0612], grad_fn=<SelectBackward>)
# 1319
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1320
# tensor([0.0622], grad_fn=<SelectBackward>)
# 1321
# tensor([0.0612], grad_fn=<SelectBackward>)
# 1322
# tensor([0.0626], grad_fn=<SelectBackward>)
# 1323
# tensor([0.0616], grad_fn=<SelectBackward>)
# 1324
# tensor([0.0612], grad_fn=<SelectBackward>)
# 1325
# tensor([0.0631], grad_fn=<SelectBackward>)
# 1326
# tensor([0.0612], grad_fn=<SelectBackward>)
# 1327
# tensor([0.0637], grad_fn=<SelectBackward>)
# 1328
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1329
# tensor([0.0629], grad_fn=<SelectBackward>)
# 1330
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1331
# tensor([0.0625], grad_fn=<SelectBackward>)
# 1332
# tensor([0.0614], grad_fn=<SelectBackward>)
# 1333
# tensor([0.0639], grad_fn=<SelectBackward>)
# 1334
# tensor([0.0630], grad_fn=<SelectBackward>)
# 1335
# tensor([0.0629], grad_fn=<SelectBackward>)
# 1336
# tensor([0.0645], grad_fn=<SelectBackward>)
# 1337
# tensor([0.0614], grad_fn=<SelectBackward>)
# 1338
# tensor([0.0632], grad_fn=<SelectBackward>)
# 1339
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1340
# tensor([0.0638], grad_fn=<SelectBackward>)
# 1341
# tensor([0.0656], grad_fn=<SelectBackward>)
# 1342
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1343
# tensor([0.0635], grad_fn=<SelectBackward>)
# 1344
# tensor([0.0648], grad_fn=<SelectBackward>)
# 1345
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1346
# tensor([0.0647], grad_fn=<SelectBackward>)
# 1347
# tensor([0.0640], grad_fn=<SelectBackward>)
# 1348
# tensor([0.0646], grad_fn=<SelectBackward>)
# 1349
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1350
# tensor([0.0626], grad_fn=<SelectBackward>)
# 1351
# tensor([0.0624], grad_fn=<SelectBackward>)
# 1352
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1353
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1354
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1355
# tensor([0.0613], grad_fn=<SelectBackward>)
# 1356
# tensor([0.0613], grad_fn=<SelectBackward>)
# 1357
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1358
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1359
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1360
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1361
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1362
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1363
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1364
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1365
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1366
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1367
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1368
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1369
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1370
# tensor([0.0612], grad_fn=<SelectBackward>)
# 1371
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1372
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1373
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1374
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1375
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1376
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1377
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1378
# tensor([0.0614], grad_fn=<SelectBackward>)
# 1379
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1380
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1381
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1382
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1383
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1384
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1385
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1386
# tensor([0.0612], grad_fn=<SelectBackward>)
# 1387
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1388
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1389
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1390
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1391
# tensor([0.0613], grad_fn=<SelectBackward>)
# 1392
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1393
# tensor([0.0613], grad_fn=<SelectBackward>)
# 1394
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1395
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1396
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1397
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1398
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1399
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1400
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1401
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1402
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1403
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1404
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1405
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1406
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1407
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1408
# tensor([0.0612], grad_fn=<SelectBackward>)
# 1409
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1410
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1411
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1412
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1413
# tensor([0.0616], grad_fn=<SelectBackward>)
# 1414
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1415
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1416
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1417
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1418
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1419
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1420
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1421
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1422
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1423
# tensor([0.0613], grad_fn=<SelectBackward>)
# 1424
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1425
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1426
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1427
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1428
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1429
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1430
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1431
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1432
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1433
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1434
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1435
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1436
# tensor([0.0612], grad_fn=<SelectBackward>)
# 1437
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1438
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1439
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1440
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1441
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1442
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1443
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1444
# tensor([0.0614], grad_fn=<SelectBackward>)
# 1445
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1446
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1447
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1448
# tensor([0.0612], grad_fn=<SelectBackward>)
# 1449
# tensor([0.0618], grad_fn=<SelectBackward>)
# 1450
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1451
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1452
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1453
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1454
# tensor([0.0612], grad_fn=<SelectBackward>)
# 1455
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1456
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1457
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1458
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1459
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1460
# tensor([0.0615], grad_fn=<SelectBackward>)
# 1461
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1462
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1463
# tensor([0.0612], grad_fn=<SelectBackward>)
# 1464
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1465
# tensor([0.0616], grad_fn=<SelectBackward>)
# 1466
# tensor([0.0612], grad_fn=<SelectBackward>)
# 1467
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1468
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1469
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1470
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1471
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1472
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1473
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1474
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1475
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1476
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1477
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1478
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1479
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1480
# tensor([0.0627], grad_fn=<SelectBackward>)
# 1481
# tensor([0.0627], grad_fn=<SelectBackward>)
# 1482
# tensor([0.0617], grad_fn=<SelectBackward>)
# 1483
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1484
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1485
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1486
# tensor([0.0619], grad_fn=<SelectBackward>)
# 1487
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1488
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1489
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1490
# tensor([0.0612], grad_fn=<SelectBackward>)
# 1491
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1492
# tensor([0.0612], grad_fn=<SelectBackward>)
# 1493
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1494
# tensor([0.0612], grad_fn=<SelectBackward>)
# 1495
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1496
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1497
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1498
# tensor([0.0614], grad_fn=<SelectBackward>)
# 1499
# tensor([0.0613], grad_fn=<SelectBackward>)
# 1500
# tensor([0.0613], grad_fn=<SelectBackward>)
# 1501
# tensor([0.0616], grad_fn=<SelectBackward>)
# 1502
# tensor([0.0620], grad_fn=<SelectBackward>)
# 1503
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1504
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1505
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1506
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1507
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1508
# tensor([0.0632], grad_fn=<SelectBackward>)
# 1509
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1510
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1511
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1512
# tensor([0.0617], grad_fn=<SelectBackward>)
# 1513
# tensor([0.0629], grad_fn=<SelectBackward>)
# 1514
# tensor([0.0613], grad_fn=<SelectBackward>)
# 1515
# tensor([0.0614], grad_fn=<SelectBackward>)
# 1516
# tensor([0.0622], grad_fn=<SelectBackward>)
# 1517
# tensor([0.0612], grad_fn=<SelectBackward>)
# 1518
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1519
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1520
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1521
# tensor([0.0613], grad_fn=<SelectBackward>)
# 1522
# tensor([0.0628], grad_fn=<SelectBackward>)
# 1523
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1524
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1525
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1526
# tensor([0.0628], grad_fn=<SelectBackward>)
# 1527
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1528
# tensor([0.0615], grad_fn=<SelectBackward>)
# 1529
# tensor([0.0618], grad_fn=<SelectBackward>)
# 1530
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1531
# tensor([0.0612], grad_fn=<SelectBackward>)
# 1532
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1533
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1534
# tensor([0.0615], grad_fn=<SelectBackward>)
# 1535
# tensor([0.0616], grad_fn=<SelectBackward>)
# 1536
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1537
# tensor([0.0625], grad_fn=<SelectBackward>)
# 1538
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1539
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1540
# tensor([0.0612], grad_fn=<SelectBackward>)
# 1541
# tensor([0.0615], grad_fn=<SelectBackward>)
# 1542
# tensor([0.0614], grad_fn=<SelectBackward>)
# 1543
# tensor([0.0613], grad_fn=<SelectBackward>)
# 1544
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1545
# tensor([0.0619], grad_fn=<SelectBackward>)
# 1546
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1547
# tensor([0.0646], grad_fn=<SelectBackward>)
# 1548
# tensor([0.0615], grad_fn=<SelectBackward>)
# 1549
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1550
# tensor([0.0614], grad_fn=<SelectBackward>)
# 1551
# tensor([0.0620], grad_fn=<SelectBackward>)
# 1552
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1553
# tensor([0.0616], grad_fn=<SelectBackward>)
# 1554
# tensor([0.0621], grad_fn=<SelectBackward>)
# 1555
# tensor([0.0628], grad_fn=<SelectBackward>)
# 1556
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1557
# tensor([0.0620], grad_fn=<SelectBackward>)
# 1558
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1559
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1560
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1561
# tensor([0.0636], grad_fn=<SelectBackward>)
# 1562
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1563
# tensor([0.0617], grad_fn=<SelectBackward>)
# 1564
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1565
# tensor([0.0628], grad_fn=<SelectBackward>)
# 1566
# tensor([0.0627], grad_fn=<SelectBackward>)
# 1567
# tensor([0.0628], grad_fn=<SelectBackward>)
# 1568
# tensor([0.0627], grad_fn=<SelectBackward>)
# 1569
# tensor([0.0631], grad_fn=<SelectBackward>)
# 1570
# tensor([0.0624], grad_fn=<SelectBackward>)
# 1571
# tensor([0.0613], grad_fn=<SelectBackward>)
# 1572
# tensor([0.0635], grad_fn=<SelectBackward>)
# 1573
# tensor([0.0627], grad_fn=<SelectBackward>)
# 1574
# tensor([0.0623], grad_fn=<SelectBackward>)
# 1575
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1576
# tensor([0.0632], grad_fn=<SelectBackward>)
# 1577
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1578
# tensor([0.0612], grad_fn=<SelectBackward>)
# 1579
# tensor([0.0633], grad_fn=<SelectBackward>)
# 1580
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1581
# tensor([0.0612], grad_fn=<SelectBackward>)
# 1582
# tensor([0.0614], grad_fn=<SelectBackward>)
# 1583
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1584
# tensor([0.0615], grad_fn=<SelectBackward>)
# 1585
# tensor([0.0614], grad_fn=<SelectBackward>)
# 1586
# tensor([0.0631], grad_fn=<SelectBackward>)
# 1587
# tensor([0.0619], grad_fn=<SelectBackward>)
# 1588
# tensor([0.0632], grad_fn=<SelectBackward>)
# 1589
# tensor([0.0640], grad_fn=<SelectBackward>)
# 1590
# tensor([0.0629], grad_fn=<SelectBackward>)
# 1591
# tensor([0.0637], grad_fn=<SelectBackward>)
# 1592
# tensor([0.0626], grad_fn=<SelectBackward>)
# 1593
# tensor([0.0627], grad_fn=<SelectBackward>)
# 1594
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1595
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1596
# tensor([0.0625], grad_fn=<SelectBackward>)
# 1597
# tensor([0.0631], grad_fn=<SelectBackward>)
# 1598
# tensor([0.0627], grad_fn=<SelectBackward>)
# 1599
# tensor([0.0626], grad_fn=<SelectBackward>)
# 1600
# tensor([0.0640], grad_fn=<SelectBackward>)
# 1601
# tensor([0.0610], grad_fn=<SelectBackward>)
# 1602
# tensor([0.0629], grad_fn=<SelectBackward>)
# 1603
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1604
# tensor([0.0626], grad_fn=<SelectBackward>)
# 1605
# tensor([0.0639], grad_fn=<SelectBackward>)
# 1606
# tensor([0.0626], grad_fn=<SelectBackward>)
# 1607
# tensor([0.0617], grad_fn=<SelectBackward>)
# 1608
# tensor([0.0647], grad_fn=<SelectBackward>)
# 1609
# tensor([0.0611], grad_fn=<SelectBackward>)
# 1610
# tensor([0.0612], grad_fn=<SelectBackward>)
# 1611
# tensor([0.0624], grad_fn=<SelectBackward>)
# 1612
# tensor([0.0622], grad_fn=<SelectBackward>)
# 1613
# tensor([0.0636], grad_fn=<SelectBackward>)
# 1614
# tensor([0.0630], grad_fn=<SelectBackward>)
# 1615
# tensor([0.0646], grad_fn=<SelectBackward>)
# 1616
# tensor([0.0625], grad_fn=<SelectBackward>)
# 1617
# tensor([0.0624], grad_fn=<SelectBackward>)
# 1618
# tensor([0.0637], grad_fn=<SelectBackward>)
# 1619
# tensor([0.0624], grad_fn=<SelectBackward>)
# 1620
# tensor([0.0637], grad_fn=<SelectBackward>)
# 1621
# tensor([0.0617], grad_fn=<SelectBackward>)
# 1622
# tensor([0.0647], grad_fn=<SelectBackward>)

# %%
import torch
import torch.utils.data as Data

torch.manual_seed(1)   # 确保每次取的数据一致，使得实验结果一致

# 准备数据
x = torch.linspace(1,10,10)
y = torch.linspace(10,1,10)

# 转换成torch可以识别的Dataset
torch_dataset = Data.TensorDataset(x, y)    # 得到一个元组(x, y)

# 将dataset 放入DataLoader
loader = Data.DataLoader(
    dataset=torch_dataset,
    batch_size=5,
    shuffle=True,  # 每次训练打乱数据， 默认为False
    num_workers=0,  # 使用多进行程读取数据， 默认0，为不使用多进程
)

if __name__ == "__main__":
    # train
    for epoch in range(3):
        for step, (batch_x, batch_y) in enumerate(loader):
            print("Epoch: ", epoch, "| Step: ", step, "| batch x:",
                  batch_x.numpy(), "| batch y: ", batch_y.numpy())
# Out:
# Epoch:  0 | Step:  0 | batch x: [ 5.  7. 10.  3.  4.] | batch y:  [6. 4. 1. 8. 7.]
# Epoch:  0 | Step:  1 | batch x: [2. 1. 8. 9. 6.] | batch y:  [ 9. 10.  3.  2.  5.]
# Epoch:  1 | Step:  0 | batch x: [ 4.  6.  7. 10.  8.] | batch y:  [7. 5. 4. 1. 3.]
# Epoch:  1 | Step:  1 | batch x: [5. 3. 2. 1. 9.] | batch y:  [ 6.  8.  9. 10.  2.]
# Epoch:  2 | Step:  0 | batch x: [ 4.  2.  5.  6. 10.] | batch y:  [7. 9. 6. 5. 1.]
# Epoch:  2 | Step:  1 | batch x: [3. 9. 1. 8. 7.] | batch y:  [ 8.  2. 10.  3.  4.]
